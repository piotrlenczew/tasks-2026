# %%
import duckdb

duckdb.sql("COPY (SELECT * FROM 'data.csv' WHERE period = 'train') TO 'train.csv' (HEADER, DELIMITER ',')")
duckdb.sql("COPY (SELECT * FROM 'data.csv' WHERE period = 'test') TO 'test.csv' (HEADER, DELIMITER ',')")
duckdb.sql("COPY (SELECT * FROM 'data.csv' WHERE period = 'valid') TO 'valid.csv' (HEADER, DELIMITER ',')")
